# %% [markdown]
# # 1. Marcdown cells
# * Hi! Its Main Academy?
# * All HTML tabs are supported!
# * Моя сторінка на лінкедін [Лінкедін](https://www.linkedin.com/feed/)
#
# # This is Heading 1
# ## This is Heading 2
# some gray colored text:
# > This is where we can bring quotes and present them nicely
#
# And this is paragraph about something very important. Even math:
# $$\gamma _{sub}=\sqrt{(x_{sub})}$$

# %% [markdown]
# $$\bar{y}=\frac{1}{n}\sum_{n}^{i=1}Yi$$

# %% [markdown]
# $$\sigma ^{2}=\frac{\sum_{i=1}^{n}(y_{i-\bar{y}})^{2}}{n-1}$$

# %% [markdown]
# $$\sigma =\sqrt{\sigma ^{2}=\frac{\sum_{i=1}^{n}(y_{i-\bar{y}})^{2}}{n-1}}$$
